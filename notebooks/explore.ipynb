# %% [markdown]
# # Pump fleet exploration
#
# Where the failure score sits across the fleet.

# %%
import pandas as pd

frame = pd.read_csv("../data/sensor_readings.csv")
frame[["vibration_rms", "temp_c", "failure_score"]].describe()

# %%
frame.groupby("pump_id")["failure_score"].mean().sort_values().tail(10)
